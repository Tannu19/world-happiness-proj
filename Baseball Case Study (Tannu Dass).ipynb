# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#import data
df=pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# # Data set Attributes

# %% [markdown]
# Input features: Runs (R), At Bats (AB), Hits (H), Doubles (2B), Triples (3B), Homeruns (HR), Walks (BB), Strikeouts (SO), Stolen Bases (SB), Runs Allowed (RA), Earned Runs (ER), Earned Run Average (ERA), Shutouts (SHO), Saves (SV), Complete Games (CG) and Errors (E)
# Output: Number of predicted wins (W)

# %% [markdown]
# # EDA of Dataset

# %%
#To get no of rows & columns in the dataset
df.shape
# Out:
# (30, 17)

# %% [markdown]
# 13 rows & 17 columns

# %%
#Data Type in the dataset
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# Int & float type data is available & no str data is there in the given dataset respectivey. Also data is continous so we can use linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#summary of a Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
# Check null values in the dataset
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There is no null value present in the dataset

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# Observations:
#     1) mean value is more than 50th median in AB(At Bats), H(Hits), 3B(Triples), HR(Homeruns),CG(Complete Games), SV(Saves) columns.
#     2) There is a large difference in 75th median and max in the R, AB, H, 2B, HR, SO, SB, RA, ER & E columns.
#     Above two observations indicates that outliers present in these columns.

# %%
#Exploring the data variable
df.W.unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %% [markdown]
# min value= 63 (low wins) & max value= 100(high wins)

# %%
df.W.value_counts()
# Out:
# 68     3
# 81     2
# 74     2
# 76     2
# 83     2
# 80     1
# 97     1
# 98     1
# 67     1
# 71     1
# 78     1
# 79     1
# 95     1
# 100    1
# 92     1
# 84     1
# 85     1
# 86     1
# 87     1
# 88     1
# 90     1
# 63     1
# 93     1
# 64     1
# Name: W, dtype: int64

# %% [markdown]
# W (wins) has most values concentrated in category of 68.

# %% [markdown]
# # Data Visualization

# %%
#to check missing values in data set via heat map
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# No missing values in dataset as plot have single color

# %%
#to check distribution of single variables and relationships between two variables
sns.pairplot(df)

# %% [markdown]
# # To check Correlations

# %%
dfcor=df.corr()
dfcor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
sns.heatmap(dfcor, annot=True)
# Out:
# <AxesSubplot:>

# %%
# to have better view
plt.figure(figsize=(15,10))
sns.heatmap(dfcor, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# E & W are highly correlated, ER & ERA are highly correlated, RA & ER are highly correlated

# %%
#graph color via Cmap
plt.figure(figsize=(15,10))
sns.heatmap(dfcor,cmap='Purples',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data distribution for Each variable to check skewness

# %%
plt.figure(figsize=(8,6))
sns.distplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
for a in df.columns:
    plt.figure()
    sns.distplot(df[a])

# %% [markdown]
# H & E are highly skewed
# 2B, RA, SV, SHO, G are somewhat skewed

# %% [markdown]
# # To find Outliers

# %%
#Univariate analysis
for a in df.columns:
    plt.figure()
    (df[a]).plot.box()

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# Observation:Outliers present in E & somewhat in SV, SHO, ERA, R

# %%
# bivariate analysis
plt.scatter(df['R'],df['W'])
plt.scatter(df['AB'],df['W'])
plt.scatter(df['H'],df['W'])
plt.scatter(df['2B'],df['W'])
plt.scatter(df['3B'],df['W'])
plt.scatter(df['HR'],df['W'])
plt.scatter(df['SO'],df['W'])
plt.scatter(df['SB'],df['W'])
plt.scatter(df['RA'],df['W'])
plt.scatter(df['ER'],df['W'])
plt.scatter(df['ERA'],df['W'])
plt.scatter(df['CG'],df['W'])
plt.scatter(df['SHO'],df['W'])
plt.scatter(df['SV'],df['W'])
plt.scatter(df['E'],df['W'])

# %% [markdown]
# # Skewness removal

# %%
from scipy import stats

# %%
E_boxcox=stats.boxcox(df['E'])[0]
pd.Series(E_boxcox).skew()
# Out:
# 0.06348390578165644

# %%
SV_boxcox=stats.boxcox(df['SV'])[0]
pd.Series(SV_boxcox).skew()
# Out:
# 0.000696458045528

# %%
H_boxcox=stats.boxcox(df['H'])[0]
pd.Series(H_boxcox).skew()
# Out:
# 0

# %%
SHO_boxcox=stats.boxcox(df['SHO'])[0]
pd.Series(SHO_boxcox).skew()
# Out:
# 0.007266193575447551

# %%
SV_boxcox=stats.boxcox(df['SV'])[0]
pd.Series(SV_boxcox).skew()
# Out:
# 0.000696458045528

# %%
ERA_boxcox=stats.boxcox(df['ERA'])[0]
pd.Series(ERA_boxcox).skew()
# Out:
# 0.002093753553159266

# %%
R_boxcox=stats.boxcox(df['R'])[0]
pd.Series(R_boxcox).skew()
# Out:
# 0.0

# %%
from sklearn import metrics

# %% [markdown]
# # Model fitting

# %%
X=df[['R','AB','H','2B','3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E']].values
y=df['W'].values

# %%
X.shape
# Out:
# (30, 16)

# %%
y.shape
# Out:
# (30,)

# %% [markdown]
# Linear regression model

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.75,random_state=0)

# %%
linreg = LinearRegression()

# %%
linreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Coefficients of model
linreg.coef_
# Out:
# array([ 0.00819764,  0.01168726, -0.00849291, -0.00283898,  0.02300848,
#         0.08219701, -0.01874371, -0.03678289, -0.01998204, -0.08103451,
#        -0.07383516, -0.00025679, -0.00762618,  0.00939986,  0.02522837,
#        -0.04188179])

# %%
linreg.intercept_
# Out:
# 168.66088671549232

# %%
#Prediction of dataset
y_pred = linreg.predict(X_test)
y_pred
# Out:
# array([56.81362097, 56.04567798, 85.67201274, 79.74200346, 95.        ,
#        67.24428943])

# %%
best_score=0
for i in range(201):
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = i)
    from sklearn.preprocessing import StandardScaler
    sc_X = StandardScaler()
    #sc_y = StandardScaler()
    X_train = sc_X.fit_transform(X_train)
    #y_train = sc_y.fit_transform(y_train)
    lr = LinearRegression()
    lr.fit(X_train,y_train)
    b_score=lr.score(sc_X.transform(X_test),y_test)
    if b_score>best_score:
        best_score=b_score
        randomState=i
    
print('Best Score = {} For Random state = {}'.format(best_score*100,randomState))
# Out:
# Best Score = 93.43338116280451 For Random state = 165

# %%
sc_X = StandardScaler()
#sc_y = StandardScaler()
X_train = sc_X.fit_transform(X_train)
#y_train = sc_y.fit_transform(y_train)

# %%
y_predlr=lr.predict(sc_X.transform(X_test))

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
print('The R2 score={}'.format(r2_score(y_test, y_pred)*100))
print('The MSE ={}'.format(mean_squared_error(y_test, y_pred)))
print('The MAE ={}'.format(mean_absolute_error(y_test, y_pred)))
print('The RMSE ={}'.format(np.sqrt(mean_squared_error(y_test, y_pred))))
# Out:
# The R2 score=59.49876669062124
# The MSE =46.66642104647309
# The MAE =5.385071302351849
# The RMSE =6.831282533058714

# %%
from scipy.stats import zscore
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %%
scr = cross_val_score(linreg,X,y,cv=5)
print('Cross validation score for Linear Regression Model is ',scr.mean())
# Out:
# Cross validation score for Linear Regression Model is  0.040755406674663285

# %% [markdown]
# Linear Regression Model Difference is 59.5 - 4.1 = 4.7

# %% [markdown]
# Ridge Regression Model Build

# %%
r = Ridge()
r.fit(X_train,y_train)
predr = r.predict(X_test)
print(r2_score(y_test,predr))
print(mean_squared_error(y_test,predr))
print(np.sqrt(mean_squared_error(y_test,predr)))
# Out:
# -5783.011349682344
# 666446.6410689546
# 816.3618321975584

# %%
scr = cross_val_score(r,X,y,cv=5)
print('Cross validation score for Ridge Regression Model is', scr.mean())
# Out:
# Cross validation score for Ridge Regression Model is -0.02152912211965874

# %% [markdown]
# Linear regression is performing well on this dataset than other regression algorithms
# Saving the Model
