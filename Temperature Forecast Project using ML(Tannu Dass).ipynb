# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#import data
df=pd.read_csv('temperature.csv')
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# 1       90.604721         29.850689         24.035009   5.691890   51.937448
# 2       83.973587         30.091292         24.565633   6.138224   20.573050
# 3       96.483688         29.704629         23.326177   5.650050   65.727144
# 4       90.155128         29.113934         23.486480   5.735004  107.965535
# ...           ...               ...               ...        ...         ...
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0     ...    0.000000    0.000000    0.000000  37.6046  126.991  212.3350
# 1     ...    0.000000    0.000000    0.000000  37.6046  127.032   44.7624
# 2     ...    0.000000    0.000000    0.000000  37.5776  127.058   33.3068
# 3     ...    0.000000    0.000000    0.000000  37.6450  127.022   45.7160
# 4     ...    0.000000    0.000000    0.000000  37.5507  127.135   35.0380
# ...   ...         ...         ...         ...      ...      ...       ...
# 7747  ...    0.000000    0.000000    0.000000  37.5372  126.891   15.5876
# 7748  ...    0.000000    0.000000    0.000000  37.5237  126.909   17.2956
# 7749  ...    0.000000    0.000000    0.000000  37.5237  126.970   19.5844
# 7750  ...    0.000000    0.000000    0.000000  37.4562  126.826   12.3700
# 7751  ...   21.621661   15.841235   16.655469  37.6450  127.135  212.3350
#
#          Slope  Solar radiation  Next_Tmax  Next_Tmin
# 0     2.785000      5992.895996       29.1       21.2
# 1     0.514100      5869.312500       30.5       22.5
# 2     0.266100      5863.555664       31.1       23.9
# 3     2.534800      5856.964844       31.7       24.3
# 4     0.505500      5859.552246       31.2       22.5
# ...        ...              ...        ...        ...
# 7747  0.155400      4443.313965       28.3       18.1
# 7748  0.222300      4438.373535       28.6       18.8
# 7749  0.271300      4451.345215       27.8       17.4
# 7750  0.098475      4329.520508       17.4       11.3
# 7751  5.178230      5992.895996       38.9       29.8
#
# [7752 rows x 25 columns]

# %% [markdown]
# # Dataset Attributes

# %% [markdown]
# The input data is largely composed of the LDAPS model's next-day forecast data, in-situ maximum and minimum temperatures of present-day, and geographic auxiliary variables. There are two outputs (i.e. next-day maximum and minimum (Next_Tmax) air temperatures (Next_Tmin))

# %% [markdown]
# # EDA of Dataset

# %%
df.shape
# Out:
# (7752, 25)

# %%
df.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %% [markdown]
# String & float type data is present in the dataset

# %%
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
#  16  LDAPS_PPT3        7677 non-null   float64
#  17  LDAPS_PPT4        7677 non-null   float64
#  18  lat               7752 non-null   float64
#  19  lon               7752 non-null   float64
#  20  DEM               7752 non-null   float64
#  21  Slope             7752 non-null   float64
#  22  Solar radiation   7752 non-null   float64
#  23  Next_Tmax         7725 non-null   float64
#  24  Next_Tmin         7725 non-null   float64
# dtypes: float64(24), object(1)
# memory usage: 1.5+ MB

# %%
#To check null values
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %% [markdown]
# Null values present in dataset

# %%
#Treating dates in the dataset
df['Date'] = pd.to_datetime(df.Date)
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# %%
df.drop('Date', inplace = True, axis = 1)
df
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0          28.7          21.4    58.255688    91.116364
# 1         2.0          31.9          21.6    52.263397    90.604721
# 2         3.0          31.6          23.3    48.690479    83.973587
# 3         4.0          32.0          23.4    58.239788    96.483688
# 4         5.0          31.4          21.9    56.174095    90.155128
# ...       ...           ...           ...          ...          ...
# 7747     23.0          23.3          17.1    26.741310    78.869858
# 7748     24.0          23.3          17.7    24.040634    77.294975
# 7749     25.0          23.2          17.4    22.933014    77.243744
# 7750      NaN          20.0          11.3    19.794666    58.936283
# 7751      NaN          37.6          29.9    98.524734   100.000153
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# 0            28.074101         23.006936   6.818887   69.451805   0.233947
# 1            29.850689         24.035009   5.691890   51.937448   0.225508
# 2            30.091292         24.565633   6.138224   20.573050   0.209344
# 3            29.704629         23.326177   5.650050   65.727144   0.216372
# 4            29.113934         23.486480   5.735004  107.965535   0.151407
# ...                ...               ...        ...         ...        ...
# 7747         26.352081         18.775678   6.148918   72.058294   0.030034
# 7748         27.010193         18.733519   6.542819   47.241457   0.035874
# 7749         27.939516         18.522965   7.289264    9.090034   0.048954
# 7750         17.624954         14.272646   2.882580  -13.603212   0.000000
# 7751         38.542255         29.619342  21.857621  213.414006   0.967277
#
#       ...      lat      lon       DEM     Slope  Solar radiation  Next_Tmax  \
# 0     ...  37.6046  126.991  212.3350  2.785000      5992.895996       29.1
# 1     ...  37.6046  127.032   44.7624  0.514100      5869.312500       30.5
# 2     ...  37.5776  127.058   33.3068  0.266100      5863.555664       31.1
# 3     ...  37.6450  127.022   45.7160  2.534800      5856.964844       31.7
# 4     ...  37.5507  127.135   35.0380  0.505500      5859.552246       31.2
# ...   ...      ...      ...       ...       ...              ...        ...
# 7747  ...  37.5372  126.891   15.5876  0.155400      4443.313965       28.3
# 7748  ...  37.5237  126.909   17.2956  0.222300      4438.373535       28.6
# 7749  ...  37.5237  126.970   19.5844  0.271300      4451.345215       27.8
# 7750  ...  37.4562  126.826   12.3700  0.098475      4329.520508       17.4
# 7751  ...  37.6450  127.135  212.3350  5.178230      5992.895996       38.9
#
#       Next_Tmin    Year  Month   Day
# 0          21.2  2013.0    6.0  30.0
# 1          22.5  2013.0    6.0  30.0
# 2          23.9  2013.0    6.0  30.0
# 3          24.3  2013.0    6.0  30.0
# 4          22.5  2013.0    6.0  30.0
# ...         ...     ...    ...   ...
# 7747       18.1  2017.0    8.0  30.0
# 7748       18.8  2017.0    8.0  30.0
# 7749       17.4  2017.0    8.0  30.0
# 7750       11.3     NaN    NaN   NaN
# 7751       29.8     NaN    NaN   NaN
#
# [7752 rows x 27 columns]

# %%
df_imp_col = ['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
       'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
       'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1',
       'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope',
       'Solar radiation', 'Next_Tmax', 'Next_Tmin', 'Year', 'Month', 'Day']

# %%
#to remove Nan Values
from sklearn.impute import KNNImputer

# %%
knni = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')

# %%
df = knni.fit_transform(df)

# %%
df = pd.DataFrame(df, columns = df_imp_col)
df.head()
# Out:
#    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0          28.7          21.4    58.255688    91.116364
# 1      2.0          31.9          21.6    52.263397    90.604721
# 2      3.0          31.6          23.3    48.690479    83.973587
# 3      4.0          32.0          23.4    58.239788    96.483688
# 4      5.0          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  ...  \
# 0         28.074101         23.006936  6.818887   69.451805   0.233947  ...
# 1         29.850689         24.035009  5.691890   51.937448   0.225508  ...
# 2         30.091292         24.565633  6.138224   20.573050   0.209344  ...
# 3         29.704629         23.326177  5.650050   65.727144   0.216372  ...
# 4         29.113934         23.486480  5.735004  107.965535   0.151407  ...
#
#        lat      lon       DEM   Slope  Solar radiation  Next_Tmax  Next_Tmin  \
# 0  37.6046  126.991  212.3350  2.7850      5992.895996       29.1       21.2
# 1  37.6046  127.032   44.7624  0.5141      5869.312500       30.5       22.5
# 2  37.5776  127.058   33.3068  0.2661      5863.555664       31.1       23.9
# 3  37.6450  127.022   45.7160  2.5348      5856.964844       31.7       24.3
# 4  37.5507  127.135   35.0380  0.5055      5859.552246       31.2       22.5
#
#      Year  Month   Day
# 0  2013.0    6.0  30.0
# 1  2013.0    6.0  30.0
# 2  2013.0    6.0  30.0
# 3  2013.0    6.0  30.0
# 4  2013.0    6.0  30.0
#
# [5 rows x 27 columns]

# %%
df.isnull().sum()
# Out:
# station             0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# Year                0
# Month               0
# Day                 0
# dtype: int64

# %%
#to check missing values in data set via heat map # Data visualization
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Same color plot so no null value in the dataset

# %%
ldaps_test = ['LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4']
for i in ldaps_test:
    print(df[i].value_counts())
    print('\n')
# Out:
# 0.000000    4871
# 0.001953      11
# 0.002604       5
# 0.253744       3
# 0.001734       3
#             ...
# 0.083498       1
# 0.188553       1
# 0.748351       1
# 2.243524       1
# 0.070813       1
# Name: LDAPS_PPT1, Length: 2855, dtype: int64
#
#
# 0.000000    5174
# 0.001953       7
# 0.010005       3
# 0.000040       3
# 0.000781       3
#             ...
# 0.170119       1
# 0.056182       1
# 0.649503       1
# 0.061178       1
# 0.083048       1
# Name: LDAPS_PPT2, Length: 2558, dtype: int64
#
#
# 0.000000    5318
# 0.001953      10
# 0.000852       4
# 0.002604       3
# 0.027203       3
#             ...
# 0.002885       1
# 1.074060       1
# 0.004680       1
# 0.034565       1
# 0.405181       1
# Name: LDAPS_PPT3, Length: 2402, dtype: int64
#
#
# 0.000000     5799
# 0.000290        4
# 0.001953        3
# 0.000199        2
# 16.655469       2
#              ...
# 0.044184        1
# 5.368769        1
# 0.113642        1
# 1.125897        1
# 0.016838        1
# Name: LDAPS_PPT4, Length: 1938, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (20,7))
sns.scatterplot(y="Solar radiation", x="station", data = df)
plt.xticks(rotation = -70, fontsize = 7)
plt.show()

# %%
plt.figure(figsize = (22,7))
sns.lineplot(y="Next_Tmax", x="Present_Tmax", data = df)
plt.xticks(rotation = -70, fontsize = 7)
plt.show()

# %%
plt.figure(figsize = (22,7))
sns.lineplot(y="Next_Tmin", x="Present_Tmin", data = df)
plt.xticks(rotation = -70, fontsize = 7)
plt.show()

# %%
plt.figure(figsize = (22,7))
sns.lineplot(y="Present_Tmax", x="Present_Tmin", data = df)
plt.xticks(rotation = -70, fontsize = 7)
plt.show()

# %%
plt.figure(figsize = (22,7))
sns.lineplot(y="Next_Tmax", x="Next_Tmin", data = df)
plt.xticks(rotation = -70, fontsize = 7)
plt.show()

# %%
plt.figure(figsize = (45,15))
sns.barplot(x = 'Year', y ='Solar radiation', data = df)
plt.xticks(rotation = -65, fontsize = 20)
plt.show()

# %% [markdown]
# Solar radiation is lowest in the year 2015.2

# %%
plt.figure(figsize = (45,15))
sns.barplot(x = 'Month', y ='Solar radiation', data = df)
plt.xticks(rotation = 70, fontsize = 20)
plt.show()

# %%
#Statistical Summary
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7752.000000   7752.000000   7752.000000  7752.000000  7752.000000
# mean     12.998865     29.769249     23.226713    56.712966    88.369128
# std       7.212017      2.963391      2.408518    14.620018     7.168515
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.973853    84.246307
# 50%      13.000000     29.900000     23.400000    54.959623    89.750568
# 75%      19.000000     32.000000     24.900000    67.078279    93.711344
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7752.000000       7752.000000  7752.000000  7752.000000
# mean          29.633310         23.526105     7.089773    62.527477
# std            2.941858          2.339946     2.176008    33.645225
# min           17.624954         14.272646     2.882580   -13.603212
# 25%           27.693091         22.114651     5.680214    37.412333
# 50%           29.744207         23.771672     6.540041    56.953214
# 75%           31.734400         25.162746     8.009219    84.192035
# max           38.542255         29.619342    21.857621   213.414006
#
#          LDAPS_CC1  ...          lat          lon          DEM        Slope  \
# count  7752.000000  ...  7752.000000  7752.000000  7752.000000  7752.000000
# mean      0.368300  ...    37.544722   126.991397    61.867972     1.257048
# std       0.261542  ...     0.050352     0.079435    54.279780     1.370444
# min       0.000000  ...    37.456200   126.826000    12.370000     0.098475
# 25%       0.148273  ...    37.510200   126.937000    28.700000     0.271300
# 50%       0.314835  ...    37.550700   126.995000    45.716000     0.618000
# 75%       0.571811  ...    37.577600   127.042000    59.832400     1.767800
# max       0.967277  ...    37.645000   127.135000   212.335000     5.178230
#
#        Solar radiation    Next_Tmax    Next_Tmin         Year        Month  \
# count      7752.000000  7752.000000  7752.000000  7752.000000  7752.000000
# mean       5341.502803    30.275544    22.934450  2015.000155     7.080547
# std         429.158867     3.125852     2.485431     1.414170     2.238181
# min        4329.520508    17.400000    11.300000  2013.000000     1.000000
# 25%        4999.018555    28.200000    21.380000  2014.000000     7.000000
# 50%        5436.345215    30.500000    23.100000  2015.000000     7.000000
# 75%        5728.316406    32.600000    24.600000  2016.000000     8.000000
# max        5992.895996    38.900000    29.800000  2017.000000    12.000000
#
#               Day
# count  7752.00000
# mean     16.37211
# std       8.24190
# min       7.00000
# 25%       8.00000
# 50%      16.00000
# 75%      24.00000
# max      31.00000
#
# [8 rows x 27 columns]

# %% [markdown]
# Observation:
#     1)Mean is greater than 50th median for the columns LDAPS_RHmin, LDAPS_LH,LDAPS_CC1, DEM, Slope,Solar radiation.
#     2) High difference exists between Max & 75th median for the columns LDAPS_LH, DEM, Solar radiation.
#     So above observations states that these columns have outliers.

# %% [markdown]
# # To check correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#                    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000      0.111977      0.130793    -0.068286
# Present_Tmax      0.111977      1.000000      0.619082    -0.208099
# Present_Tmin      0.130793      0.619082      1.000000     0.118907
# LDAPS_RHmin      -0.068286     -0.208099      0.118907     1.000000
# LDAPS_RHmax      -0.169880     -0.303987     -0.017163     0.579102
# LDAPS_Tmax_lapse  0.069209      0.575555      0.473219    -0.565266
# LDAPS_Tmin_lapse  0.105267      0.628712      0.771151     0.087108
# LDAPS_WS          0.003466     -0.126141     -0.040794     0.295407
# LDAPS_LH         -0.136223      0.136643     -0.007617    -0.069368
# LDAPS_CC1         0.006461     -0.312128      0.082155     0.613923
# LDAPS_CC2         0.002836     -0.215699      0.086708     0.745492
# LDAPS_CC3         0.000172     -0.149818     -0.010017     0.689613
# LDAPS_CC4         0.005790     -0.142690     -0.049598     0.513140
# LDAPS_PPT1       -0.005350     -0.110563      0.109754     0.263096
# LDAPS_PPT2       -0.010968     -0.101938      0.065513     0.391154
# LDAPS_PPT3       -0.015490     -0.122002     -0.047789     0.240606
# LDAPS_PPT4       -0.013331     -0.099005     -0.063393     0.169009
# lat              -0.237984     -0.053182     -0.079075     0.087941
# lon              -0.119189      0.007994     -0.044231    -0.076673
# DEM              -0.256428     -0.188616     -0.251891     0.102892
# Slope            -0.090706     -0.107051     -0.147330     0.124598
# Solar radiation  -0.019458     -0.027473      0.051563     0.246946
# Next_Tmax         0.106113      0.612460      0.473128    -0.443850
# Next_Tmin         0.127033      0.623924      0.798760     0.092158
# Year             -0.000144      0.060485      0.036438    -0.000820
# Month             0.000185     -0.001022     -0.003190    -0.057095
# Day               0.000219     -0.145105     -0.111193    -0.065166
#
#                   LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  \
# station             -0.169880          0.069209          0.105267  0.003466
# Present_Tmax        -0.303987          0.575555          0.628712 -0.126141
# Present_Tmin        -0.017163          0.473219          0.771151 -0.040794
# LDAPS_RHmin          0.579102         -0.565266          0.087108  0.295407
# LDAPS_RHmax          1.000000         -0.373480         -0.115579  0.135456
# LDAPS_Tmax_lapse    -0.373480          1.000000          0.655365 -0.313829
# LDAPS_Tmin_lapse    -0.115579          0.655365          1.000000 -0.131945
# LDAPS_WS             0.135456         -0.313829         -0.131945  1.000000
# LDAPS_LH             0.240227          0.046863         -0.134880  0.006104
# LDAPS_CC1            0.435453         -0.437941          0.010643  0.289830
# LDAPS_CC2            0.390516         -0.523415          0.046785  0.261946
# LDAPS_CC3            0.226783         -0.542163         -0.046346  0.244466
# LDAPS_CC4            0.129124         -0.429506         -0.081141  0.220940
# LDAPS_PPT1           0.268419         -0.112023          0.036897  0.153193
# LDAPS_PPT2           0.228968         -0.242860         -0.000330  0.192476
# LDAPS_PPT3           0.134456         -0.188127         -0.088816  0.161851
# LDAPS_PPT4           0.117817         -0.161167         -0.095566  0.144695
# lat                  0.197582         -0.042804         -0.097047  0.036694
# lon                  0.025747          0.090894         -0.026923 -0.059253
# DEM                  0.178312         -0.180682         -0.197330  0.193031
# Slope                0.220731         -0.163745         -0.187257  0.173084
# Solar radiation      0.150780          0.044124          0.156772  0.124307
# Next_Tmax           -0.285897          0.834871          0.593226 -0.349295
# Next_Tmin           -0.074559          0.592674          0.885756 -0.101504
# Year                -0.143430          0.016137         -0.002803 -0.110551
# Month               -0.040100         -0.018203         -0.025676 -0.084279
# Day                 -0.015130         -0.158539         -0.174118 -0.030785
#
#                   LDAPS_LH  LDAPS_CC1  ...       lat       lon       DEM  \
# station          -0.136223   0.006461  ... -0.237984 -0.119189 -0.256428
# Present_Tmax      0.136643  -0.312128  ... -0.053182  0.007994 -0.188616
# Present_Tmin     -0.007617   0.082155  ... -0.079075 -0.044231 -0.251891
# LDAPS_RHmin      -0.069368   0.613923  ...  0.087941 -0.076673  0.102892
# LDAPS_RHmax       0.240227   0.435453  ...  0.197582  0.025747  0.178312
# LDAPS_Tmax_lapse  0.046863  -0.437941  ... -0.042804  0.090894 -0.180682
# LDAPS_Tmin_lapse -0.134880   0.010643  ... -0.097047 -0.026923 -0.197330
# LDAPS_WS          0.006104   0.289830  ...  0.036694 -0.059253  0.193031
# LDAPS_LH          1.000000  -0.147413  ...  0.134166  0.025503  0.055475
# LDAPS_CC1        -0.147413   1.000000  ... -0.008254 -0.006736 -0.014202
# LDAPS_CC2        -0.263739   0.779984  ... -0.001467 -0.003446 -0.013011
# LDAPS_CC3        -0.245143   0.517463  ...  0.004175  0.016488  0.000518
# LDAPS_CC4        -0.172622   0.360736  ... -0.009246 -0.002313 -0.007927
# LDAPS_PPT1       -0.012506   0.446341  ...  0.000699 -0.001359  0.011542
# LDAPS_PPT2       -0.077358   0.389387  ...  0.019886  0.018695  0.008626
# LDAPS_PPT3        0.015608   0.168907  ...  0.034922  0.021246  0.016917
# LDAPS_PPT4        0.019813   0.091987  ...  0.013099  0.044643 -0.003573
# lat               0.134166  -0.008254  ...  1.000000  0.289029  0.033165
# lon               0.025503  -0.006736  ...  0.289029  1.000000  0.007587
# DEM               0.055475  -0.014202  ...  0.033165  0.007587  1.000000
# Slope             0.087201  -0.020810  ...  0.074763  0.038070  0.783576
# Solar radiation  -0.047632   0.220507  ...  0.038513  0.002182  0.056224
# Next_Tmax         0.158710  -0.456639  ... -0.053454  0.002489 -0.172653
# Next_Tmin        -0.055486  -0.012000  ... -0.083643 -0.047151 -0.247307
# Year              0.056223  -0.062848  ...  0.000150  0.000127  0.000236
# Month            -0.022280  -0.079813  ... -0.000286 -0.000285 -0.000317
# Day              -0.013770  -0.016234  ... -0.000524 -0.000579 -0.000402
#
#                      Slope  Solar radiation  Next_Tmax  Next_Tmin      Year  \
# station          -0.090706        -0.019458   0.106113   0.127033 -0.000144
# Present_Tmax     -0.107051        -0.027473   0.612460   0.623924  0.060485
# Present_Tmin     -0.147330         0.051563   0.473128   0.798760  0.036438
# LDAPS_RHmin       0.124598         0.246946  -0.443850   0.092158 -0.000820
# LDAPS_RHmax       0.220731         0.150780  -0.285897  -0.074559 -0.143430
# LDAPS_Tmax_lapse -0.163745         0.044124   0.834871   0.592674  0.016137
# LDAPS_Tmin_lapse -0.187257         0.156772   0.593226   0.885756 -0.002803
# LDAPS_WS          0.173084         0.124307  -0.349295  -0.101504 -0.110551
# LDAPS_LH          0.087201        -0.047632   0.158710  -0.055486  0.056223
# LDAPS_CC1        -0.020810         0.220507  -0.456639  -0.012000 -0.062848
# LDAPS_CC2        -0.018134         0.172904  -0.495901   0.029391 -0.040659
# LDAPS_CC3        -0.003413         0.122407  -0.522462  -0.059196  0.110527
# LDAPS_CC4        -0.014824         0.119824  -0.450135  -0.086103  0.106902
# LDAPS_PPT1        0.016492         0.089468  -0.122443   0.018950 -0.087592
# LDAPS_PPT2        0.010402         0.111381  -0.182145  -0.010610 -0.041379
# LDAPS_PPT3        0.025067        -0.053057  -0.196991  -0.064031  0.048153
# LDAPS_PPT4        0.000152         0.036040  -0.181925  -0.105880  0.039189
# lat               0.074763         0.038513  -0.053454  -0.083643  0.000150
# lon               0.038070         0.002182   0.002489  -0.047151  0.000127
# DEM               0.783576         0.056224  -0.172653  -0.247307  0.000236
# Slope             1.000000         0.028199  -0.103642  -0.147635  0.000246
# Solar radiation   0.028199         1.000000   0.008116   0.120355 -0.007633
# Next_Tmax        -0.103642         0.008116   1.000000   0.621160  0.059004
# Next_Tmin        -0.147635         0.120355   0.621160   1.000000  0.022551
# Year              0.000246        -0.007633   0.059004   0.022551  1.000000
# Month            -0.000322        -0.309975  -0.026655  -0.024949 -0.000061
# Day              -0.000394        -0.413497  -0.117860  -0.130948 -0.000023
#
#                      Month       Day
# station           0.000185  0.000219
# Present_Tmax     -0.001022 -0.145105
# Present_Tmin     -0.003190 -0.111193
# LDAPS_RHmin      -0.057095 -0.065166
# LDAPS_RHmax      -0.040100 -0.015130
# LDAPS_Tmax_lapse -0.018203 -0.158539
# LDAPS_Tmin_lapse -0.025676 -0.174118
# LDAPS_WS         -0.084279 -0.030785
# LDAPS_LH         -0.022280 -0.013770
# LDAPS_CC1        -0.079813 -0.016234
# LDAPS_CC2        -0.094084  0.006102
# LDAPS_CC3        -0.038972 -0.054632
# LDAPS_CC4        -0.019815 -0.043670
# LDAPS_PPT1       -0.031602 -0.021278
# LDAPS_PPT2       -0.046191 -0.002810
# LDAPS_PPT3        0.033730 -0.006941
# LDAPS_PPT4       -0.073021 -0.024298
# lat              -0.000286 -0.000524
# lon              -0.000285 -0.000579
# DEM              -0.000317 -0.000402
# Slope            -0.000322 -0.000394
# Solar radiation  -0.309975 -0.413497
# Next_Tmax        -0.026655 -0.117860
# Next_Tmin        -0.024949 -0.130948
# Year             -0.000061 -0.000023
# Month             1.000000  0.162005
# Day               0.162005  1.000000
#
# [27 rows x 27 columns]

# %%
plt.figure(figsize = (30,15))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Significant correlations are not there

# %% [markdown]
# # To check & remove outliers

# %%
cols = ['Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 
 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 
 'LDAPS_CC4', 'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4','Solar radiation', 
 'Next_Tmax', 'Next_Tmin']

# %%
for a in cols:
    df[a].plot.box()
    plt.show()

# %%
# to remove outliers
from scipy.stats import zscore

# %%
z = np.abs(zscore(df))
threshold = 3
np.where(z>3)
# Out:
# (array([  25,   25,   26, ..., 7751, 7751, 7751], dtype=int64),
#  array([ 7, 14, 14, ..., 14, 15, 16], dtype=int64))

# %%
df1 = df[(z<3).all(axis = 1)]
df1
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0          28.7          21.4    58.255688    91.116364
# 1         2.0          31.9          21.6    52.263397    90.604721
# 2         3.0          31.6          23.3    48.690479    83.973587
# 3         4.0          32.0          23.4    58.239788    96.483688
# 4         5.0          31.4          21.9    56.174095    90.155128
# ...       ...           ...           ...          ...          ...
# 7745     21.0          23.1          17.8    24.688997    78.261383
# 7746     22.0          22.5          17.4    30.094858    83.690018
# 7747     23.0          23.3          17.1    26.741310    78.869858
# 7748     24.0          23.3          17.7    24.040634    77.294975
# 7749     25.0          23.2          17.4    22.933014    77.243744
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# 0            28.074101         23.006936  6.818887   69.451805   0.233947
# 1            29.850689         24.035009  5.691890   51.937448   0.225508
# 2            30.091292         24.565633  6.138224   20.573050   0.209344
# 3            29.704629         23.326177  5.650050   65.727144   0.216372
# 4            29.113934         23.486480  5.735004  107.965535   0.151407
# ...                ...               ...       ...         ...        ...
# 7745         27.812697         18.303014  6.603253    9.614074   0.052902
# 7746         26.704905         17.814038  5.768083   82.146707   0.066461
# 7747         26.352081         18.775678  6.148918   72.058294   0.030034
# 7748         27.010193         18.733519  6.542819   47.241457   0.035874
# 7749         27.939516         18.522965  7.289264    9.090034   0.048954
#
#       ...      lat      lon       DEM   Slope  Solar radiation  Next_Tmax  \
# 0     ...  37.6046  126.991  212.3350  2.7850      5992.895996       29.1
# 1     ...  37.6046  127.032   44.7624  0.5141      5869.312500       30.5
# 2     ...  37.5776  127.058   33.3068  0.2661      5863.555664       31.1
# 3     ...  37.6450  127.022   45.7160  2.5348      5856.964844       31.7
# 4     ...  37.5507  127.135   35.0380  0.5055      5859.552246       31.2
# ...   ...      ...      ...       ...     ...              ...        ...
# 7745  ...  37.5507  127.040   26.2980  0.5721      4456.024414       27.6
# 7746  ...  37.5102  127.086   21.9668  0.1332      4441.803711       28.0
# 7747  ...  37.5372  126.891   15.5876  0.1554      4443.313965       28.3
# 7748  ...  37.5237  126.909   17.2956  0.2223      4438.373535       28.6
# 7749  ...  37.5237  126.970   19.5844  0.2713      4451.345215       27.8
#
#       Next_Tmin    Year  Month   Day
# 0          21.2  2013.0    6.0  30.0
# 1          22.5  2013.0    6.0  30.0
# 2          23.9  2013.0    6.0  30.0
# 3          24.3  2013.0    6.0  30.0
# 4          22.5  2013.0    6.0  30.0
# ...         ...     ...    ...   ...
# 7745       17.7  2017.0    8.0  30.0
# 7746       17.1  2017.0    8.0  30.0
# 7747       18.1  2017.0    8.0  30.0
# 7748       18.8  2017.0    8.0  30.0
# 7749       17.4  2017.0    8.0  30.0
#
# [6897 rows x 27 columns]

# %%
df1.shape
# Out:
# (6897, 27)

# %%
#Finding the percentage of dataloss
loss = ((7752-6897)/7752)*100
loss
# Out:
# 11.029411764705882

# %% [markdown]
# We cannot afford to loose more than 10% of the day and hence we will try using IQR.
#
# Just because we are not sure on the prediction value let us try to create 2 models and check if we can get something out of it.

# %%
df_no_out = df1
df_no_out.head()
# Out:
#    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0          28.7          21.4    58.255688    91.116364
# 1      2.0          31.9          21.6    52.263397    90.604721
# 2      3.0          31.6          23.3    48.690479    83.973587
# 3      4.0          32.0          23.4    58.239788    96.483688
# 4      5.0          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  ...  \
# 0         28.074101         23.006936  6.818887   69.451805   0.233947  ...
# 1         29.850689         24.035009  5.691890   51.937448   0.225508  ...
# 2         30.091292         24.565633  6.138224   20.573050   0.209344  ...
# 3         29.704629         23.326177  5.650050   65.727144   0.216372  ...
# 4         29.113934         23.486480  5.735004  107.965535   0.151407  ...
#
#        lat      lon       DEM   Slope  Solar radiation  Next_Tmax  Next_Tmin  \
# 0  37.6046  126.991  212.3350  2.7850      5992.895996       29.1       21.2
# 1  37.6046  127.032   44.7624  0.5141      5869.312500       30.5       22.5
# 2  37.5776  127.058   33.3068  0.2661      5863.555664       31.1       23.9
# 3  37.6450  127.022   45.7160  2.5348      5856.964844       31.7       24.3
# 4  37.5507  127.135   35.0380  0.5055      5859.552246       31.2       22.5
#
#      Year  Month   Day
# 0  2013.0    6.0  30.0
# 1  2013.0    6.0  30.0
# 2  2013.0    6.0  30.0
# 3  2013.0    6.0  30.0
# 4  2013.0    6.0  30.0
#
# [5 rows x 27 columns]

# %%
df_no_out.shape
# Out:
# (6897, 27)

# %% [markdown]
# # To check skewness

# %%
for b in cols: 
    sns.distplot(df[b], kde = True)
    plt.show()

# %%
df.skew()
# Out:
# station            -0.000111
# Present_Tmax       -0.263172
# Present_Tmin       -0.366972
# LDAPS_RHmin         0.306680
# LDAPS_RHmax        -0.849100
# LDAPS_Tmax_lapse   -0.240289
# LDAPS_Tmin_lapse   -0.590007
# LDAPS_WS            1.583093
# LDAPS_LH            0.668231
# LDAPS_CC1           0.462245
# LDAPS_CC2           0.477772
# LDAPS_CC3           0.650527
# LDAPS_CC4           0.671576
# LDAPS_PPT1          5.392290
# LDAPS_PPT2          5.776056
# LDAPS_PPT3          6.452470
# LDAPS_PPT4          6.826930
# lat                 0.087062
# lon                -0.285213
# DEM                 1.723257
# Slope               1.563020
# Solar radiation    -0.511210
# Next_Tmax          -0.339739
# Next_Tmin          -0.406029
# Year               -0.000282
# Month              -0.705146
# Day                 0.245510
# dtype: float64

# %%
from sklearn.preprocessing import power_transform

# %%
df[['LDAPS_PPT1','LDAPS_PPT2','LDAPS_PPT3','LDAPS_PPT4']]=power_transform(df[['LDAPS_PPT1','LDAPS_PPT2','LDAPS_PPT3','LDAPS_PPT4']])

# %%
df.skew()
# Out:
# station            -0.000111
# Present_Tmax       -0.263172
# Present_Tmin       -0.366972
# LDAPS_RHmin         0.306680
# LDAPS_RHmax        -0.849100
# LDAPS_Tmax_lapse   -0.240289
# LDAPS_Tmin_lapse   -0.590007
# LDAPS_WS            1.583093
# LDAPS_LH            0.668231
# LDAPS_CC1           0.462245
# LDAPS_CC2           0.477772
# LDAPS_CC3           0.650527
# LDAPS_CC4           0.671576
# LDAPS_PPT1          1.446305
# LDAPS_PPT2          1.628709
# LDAPS_PPT3          1.804874
# LDAPS_PPT4          2.052019
# lat                 0.087062
# lon                -0.285213
# DEM                 1.723257
# Slope               1.563020
# Solar radiation    -0.511210
# Next_Tmax          -0.339739
# Next_Tmin          -0.406029
# Year               -0.000282
# Month              -0.705146
# Day                 0.245510
# dtype: float64

# %% [markdown]
# Skewness removed

# %%
df.isnull().sum()
# Out:
# station             0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# Year                0
# Month               0
# Day                 0
# dtype: int64

# %% [markdown]
# As target variables are float we use linear regression model

# %%
#Dividing data into x and y
x = df.drop(['Next_Tmax', 'Next_Tmin'], axis = 1)
y = df[['Next_Tmax', 'Next_Tmin']]

# %%
x.head()
# Out:
#    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0          28.7          21.4    58.255688    91.116364
# 1      2.0          31.9          21.6    52.263397    90.604721
# 2      3.0          31.6          23.3    48.690479    83.973587
# 3      4.0          32.0          23.4    58.239788    96.483688
# 4      5.0          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  ...  \
# 0         28.074101         23.006936  6.818887   69.451805   0.233947  ...
# 1         29.850689         24.035009  5.691890   51.937448   0.225508  ...
# 2         30.091292         24.565633  6.138224   20.573050   0.209344  ...
# 3         29.704629         23.326177  5.650050   65.727144   0.216372  ...
# 4         29.113934         23.486480  5.735004  107.965535   0.151407  ...
#
#    LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# 0   -0.496929   -0.446026  37.6046  126.991  212.3350  2.7850
# 1   -0.496929   -0.446026  37.6046  127.032   44.7624  0.5141
# 2   -0.496929   -0.446026  37.5776  127.058   33.3068  0.2661
# 3   -0.496929   -0.446026  37.6450  127.022   45.7160  2.5348
# 4   -0.496929   -0.446026  37.5507  127.135   35.0380  0.5055
#
#    Solar radiation    Year  Month   Day
# 0      5992.895996  2013.0    6.0  30.0
# 1      5869.312500  2013.0    6.0  30.0
# 2      5863.555664  2013.0    6.0  30.0
# 3      5856.964844  2013.0    6.0  30.0
# 4      5859.552246  2013.0    6.0  30.0
#
# [5 rows x 25 columns]

# %%
y.head()
# Out:
#    Next_Tmax  Next_Tmin
# 0       29.1       21.2
# 1       30.5       22.5
# 2       31.1       23.9
# 3       31.7       24.3
# 4       31.2       22.5

# %%
#Another model
x_wo = df_no_out.drop(['Next_Tmax', 'Next_Tmin'], axis = 1)
y_wo = df_no_out[['Next_Tmax', 'Next_Tmin']]

# %%
x_wo.head()
# Out:
#    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0          28.7          21.4    58.255688    91.116364
# 1      2.0          31.9          21.6    52.263397    90.604721
# 2      3.0          31.6          23.3    48.690479    83.973587
# 3      4.0          32.0          23.4    58.239788    96.483688
# 4      5.0          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  ...  \
# 0         28.074101         23.006936  6.818887   69.451805   0.233947  ...
# 1         29.850689         24.035009  5.691890   51.937448   0.225508  ...
# 2         30.091292         24.565633  6.138224   20.573050   0.209344  ...
# 3         29.704629         23.326177  5.650050   65.727144   0.216372  ...
# 4         29.113934         23.486480  5.735004  107.965535   0.151407  ...
#
#    LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# 0         0.0         0.0  37.6046  126.991  212.3350  2.7850
# 1         0.0         0.0  37.6046  127.032   44.7624  0.5141
# 2         0.0         0.0  37.5776  127.058   33.3068  0.2661
# 3         0.0         0.0  37.6450  127.022   45.7160  2.5348
# 4         0.0         0.0  37.5507  127.135   35.0380  0.5055
#
#    Solar radiation    Year  Month   Day
# 0      5992.895996  2013.0    6.0  30.0
# 1      5869.312500  2013.0    6.0  30.0
# 2      5863.555664  2013.0    6.0  30.0
# 3      5856.964844  2013.0    6.0  30.0
# 4      5859.552246  2013.0    6.0  30.0
#
# [5 rows x 25 columns]

# %%
y_wo.head()
# Out:
#    Next_Tmax  Next_Tmin
# 0       29.1       21.2
# 1       30.5       22.5
# 2       31.1       23.9
# 3       31.7       24.3
# 4       31.2       22.5

# %%
from sklearn.preprocessing import PowerTransformer

# %%
#Removing the skewness in the x variable (with outliers)
pt = PowerTransformer(method='yeo-johnson')

# %%
x = pt.fit_transform(x)
x_wo = pt.fit_transform(x_wo)

# %%
x_cols = ['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
       'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
       'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1',
       'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope',
       'Solar radiation', 'Year', 'Month', 'Day']

# %%
x = pd.DataFrame(x, columns = x_cols)
x.head()
# Out:
#     station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0 -1.859780     -0.408480     -0.796919     0.177609     0.273125
# 1 -1.647833      0.702900     -0.719541    -0.236202     0.186248
# 2 -1.454324      0.593734     -0.028752    -0.495825    -0.771297
# 3 -1.273463      0.739518      0.013736     0.176543     1.314025
# 4 -1.102081      0.521529     -0.601943     0.036714     0.111557
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  ...  \
# 0         -0.563788         -0.319975  0.100425  0.309679  -0.407959  ...
# 1          0.034292          0.135699 -0.618907 -0.211122  -0.447062  ...
# 2          0.117560          0.385617 -0.307808 -1.372196  -0.523240  ...
# 3         -0.015993         -0.182444 -0.650135  0.203745  -0.489908  ...
# 4         -0.217322         -0.112047 -0.587120  1.297106  -0.810987  ...
#
#    LDAPS_PPT3  LDAPS_PPT4  lat       lon       DEM     Slope  Solar radiation  \
# 0   -0.590907   -0.525585  0.0 -0.027632  1.834978  1.314153         1.849430
# 1   -0.590907   -0.525585  0.0  0.497283  0.055979 -0.385336         1.400702
# 2   -0.590907   -0.525585  0.0  0.836548 -0.364575 -0.949164         1.380650
# 3   -0.590907   -0.525585  0.0  0.368125  0.084879  1.235263         1.357783
# 4   -0.590907   -0.525585  0.0  1.871193 -0.290442 -0.401730         1.366748
#
#        Year     Month       Day
# 0 -1.414465 -0.582312  1.418607
# 1 -1.414465 -0.582312  1.418607
# 2 -1.414465 -0.582312  1.418607
# 3 -1.414465 -0.582312  1.418607
# 4 -1.414465 -0.582312  1.418607
#
# [5 rows x 25 columns]

# %%
x_wo = pd.DataFrame(x_wo, columns = x_cols)
x_wo.head()
# Out:
#     station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0 -1.871161     -0.480902     -0.847404     0.261086     0.348095
# 1 -1.658603      0.665534     -0.765729    -0.171062     0.260555
# 2 -1.464532      0.552522     -0.046632    -0.441918    -0.723156
# 3 -1.283141      0.703460     -0.002953     0.259973     1.379796
# 4 -1.111255      0.477819     -0.642058     0.113889     0.185092
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  ...  \
# 0         -0.682225         -0.367215  0.179043  0.347609  -0.310397  ...
# 1         -0.042357          0.100776 -0.576227 -0.170916  -0.351767  ...
# 2          0.045724          0.354257 -0.251849 -1.385413  -0.432632  ...
# 3         -0.095662         -0.225128 -0.608608  0.243178  -0.397205  ...
# 4         -0.309970         -0.152687 -0.543234  1.299432  -0.741269  ...
#
#    LDAPS_PPT3  LDAPS_PPT4  lat       lon       DEM     Slope  Solar radiation  \
# 0   -0.466139    -0.41484  0.0 -0.019997  1.854411  1.329637         1.889291
# 1   -0.466139    -0.41484  0.0  0.503362  0.069695 -0.374203         1.434084
# 2   -0.466139    -0.41484  0.0  0.841623 -0.353347 -0.943116         1.413731
# 3   -0.466139    -0.41484  0.0  0.374587  0.098752  1.251068         1.390520
# 4   -0.466139    -0.41484  0.0  1.873207 -0.278748 -0.390725         1.399621
#
#    Year     Month       Day
# 0   0.0 -0.583813  1.419717
# 1   0.0 -0.583813  1.419717
# 2   0.0 -0.583813  1.419717
# 3   0.0 -0.583813  1.419717
# 4   0.0 -0.583813  1.419717
#
# [5 rows x 25 columns]

# %%
x.skew()
# Out:
# station            -0.204710
# Present_Tmax       -0.036078
# Present_Tmin       -0.013699
# LDAPS_RHmin        -0.017200
# LDAPS_RHmax        -0.116473
# LDAPS_Tmax_lapse   -0.011809
# LDAPS_Tmin_lapse   -0.021195
# LDAPS_WS            0.003522
# LDAPS_LH            0.055268
# LDAPS_CC1           0.048560
# LDAPS_CC2           0.047504
# LDAPS_CC3           0.092295
# LDAPS_CC4           0.131077
# LDAPS_PPT1          1.051127
# LDAPS_PPT2          1.180510
# LDAPS_PPT3          1.242783
# LDAPS_PPT4          1.490834
# lat                 0.000000
# lon                -0.198429
# DEM                 0.039456
# Slope               0.233968
# Solar radiation    -0.176636
# Year               -0.000298
# Month               0.043745
# Day                -0.041816
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
x = ss.fit_transform(x)
x_wo = ss.fit_transform(x_wo)

# %%
x = pd.DataFrame(x, columns = x_cols)
x_wo = pd.DataFrame(x_wo, columns = x_cols)

# %% [markdown]
# # Model Fitting & Testing

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
lr = LinearRegression()
knr = KNeighborsRegressor()
dtr = DecisionTreeRegressor()
rfr = RandomForestRegressor()
ls = Lasso()
rd = Ridge()
eln = ElasticNet()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 77)

# %%
x_train.shape
# Out:
# (5426, 25)

# %%
x_test.shape
# Out:
# (2326, 25)

# %%
y_train.shape
# Out:
# (5426, 2)

# %%
y_test.shape
# Out:
# (2326, 2)

# %%
model = [lr, knr, dtr, rfr, ls, rd, eln]
for m in model:
    print(m)
    m.fit(x_train, y_train)
    a = m.score(x_train, y_train)
    pred_test = m.predict(x_test)
    pred_train = m.predict(x_train)
    print('Score: ', a)
    print('Mean absolute error: ', mean_absolute_error(y_test,pred_test))
    print('Mean squared error: ', mean_squared_error(y_test,pred_test))
    print('Root mean squared error: ', np.sqrt(mean_squared_error(y_test,pred_test)))
    print('R2 Score: ', r2_score(y_test,pred_test))
    print('\n\n')
# Out:
# LinearRegression()
# Score:  0.8048658597108558
# Mean absolute error:  0.9771252062738843
# Mean squared error:  1.6727866911550369
# Root mean squared error:  1.2933625520924275
# R2 Score:  0.796231310807205
#
#
#
# KNeighborsRegressor()
# Score:  0.9212473947366815
# Mean absolute error:  0.7155382631126381
# Mean squared error:  0.8990374926913158
# Root mean squared error:  0.9481758764550572
# R2 Score:  0.8842791939486723
#
#
#
# DecisionTreeRegressor()
# Score:  1.0
# Mean absolute error:  1.0101418744625934
# Mean squared error:  2.0062950128976826
# Root mean squared error:  1.4164374369867816
# R2 Score:  0.7504250132810156
#
#
#
# RandomForestRegressor()
# Score:  0.9859359924383955
# Mean absolute error:  0.6647407136715391
# Mean squared error:  0.8005549042734311
# Root mean squared error:  0.8947373381464703
# R2 Score:  0.8993898699131468
#
#
#
# Lasso()
# Score:  0.6074422075947354
# Mean absolute error:  1.393719956731326
# Mean squared error:  3.152672818751247
# Root mean squared error:  1.7755767566487366
# R2 Score:  0.6064211446588721
#
#
#
# Ridge()
# Score:  0.8048657891788
# Mean absolute error:  0.9771028832993216
# Mean squared error:  1.6726982647196542
# Root mean squared error:  1.293328366935348
# R2 Score:  0.7962410313536646
#
#
#
# ElasticNet()
# Score:  0.6607975315560448
# Mean absolute error:  1.3000431022899699
# Mean squared error:  2.736784362397688
# Root mean squared error:  1.6543229317148718
# R2 Score:  0.6593394304785587

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

# %%
model = [lr, knr, dtr, rfr, ls, rd, eln]
for m in model:
    print('The model is: \n',m)
    for j in range (2,10):
        test_accuracy = r2_score(y_test, pred_test)
        cv_score = cross_val_score(m, x, y, cv = j)
        cv_mean = cv_score.mean()
        print(f'At cross fold {j} the cv score is {cv_mean}')
        print('\n\n')
# Out:
# The model is:
#  LinearRegression()
# At cross fold 2 the cv score is 0.6897294423226229
#
#
#
# At cross fold 3 the cv score is 0.7246288235830082
#
#
#
# At cross fold 4 the cv score is 0.7327953835083171
#
#
#
# At cross fold 5 the cv score is 0.7212383833554374
#
#
#
# At cross fold 6 the cv score is 0.719362992505093
#
#
#
# At cross fold 7 the cv score is 0.7252051428219595
#
#
#
# At cross fold 8 the cv score is 0.7258335282143753
#
#
#
# At cross fold 9 the cv score is 0.6581343355098925
#
#
#
# The model is:
#  KNeighborsRegressor()
# At cross fold 2 the cv score is 0.4948882537858221
#
#
#
# At cross fold 3 the cv score is 0.5374314050007701
#
#
#
# At cross fold 4 the cv score is 0.526368212431045
#
#
#
# At cross fold 5 the cv score is 0.5237670889447728
#
#
#
# At cross fold 6 the cv score is 0.5205257163127156
#
#
#
# At cross fold 7 the cv score is 0.5228063363986761
#
#
#
# At cross fold 8 the cv score is 0.5188657879170507
#
#
#
# At cross fold 9 the cv score is 0.39224549507621886
#
#
#
# The model is:
#  DecisionTreeRegressor()
# At cross fold 2 the cv score is 0.45558793240767004
#
#
#
# At cross fold 3 the cv score is 0.43417001754096735
#
#
#
# At cross fold 4 the cv score is 0.46570258530565606
#
#
#
# At cross fold 5 the cv score is 0.4569938080583091
#
#
#
# At cross fold 6 the cv score is 0.4047231277383705
#
#
#
# At cross fold 7 the cv score is 0.40097738968796126
#
#
#
# At cross fold 8 the cv score is 0.42408614396526384
#
#
#
# At cross fold 9 the cv score is 0.26623292611222765
#
#
#
# The model is:
#  RandomForestRegressor()
# At cross fold 2 the cv score is 0.6951870296985277
#
#
#
# At cross fold 3 the cv score is 0.7085085325293002
#
#
#
# At cross fold 4 the cv score is 0.7113758166181212
#
#
#
# At cross fold 5 the cv score is 0.7120600690898872
#
#
#
# At cross fold 6 the cv score is 0.6951418865242833
#
#
#
# At cross fold 7 the cv score is 0.7012260725610098
#
#
#
# At cross fold 8 the cv score is 0.6974234675988151
#
#
#
# At cross fold 9 the cv score is 0.6199713158155914
#
#
#
# The model is:
#  Lasso()
# At cross fold 2 the cv score is 0.5379413463006335
#
#
#
# At cross fold 3 the cv score is 0.5238393679080786
#
#
#
# At cross fold 4 the cv score is 0.5539762688934146
#
#
#
# At cross fold 5 the cv score is 0.5525600561297821
#
#
#
# At cross fold 6 the cv score is 0.5287172398416117
#
#
#
# At cross fold 7 the cv score is 0.5388444702895839
#
#
#
# At cross fold 8 the cv score is 0.5243930348825872
#
#
#
# At cross fold 9 the cv score is 0.34505313313189795
#
#
#
# The model is:
#  Ridge()
# At cross fold 2 the cv score is 0.689884142647611
#
#
#
# At cross fold 3 the cv score is 0.7246785595069246
#
#
#
# At cross fold 4 the cv score is 0.732820508628399
#
#
#
# At cross fold 5 the cv score is 0.7212713897469871
#
#
#
# At cross fold 6 the cv score is 0.7193817756053603
#
#
#
# At cross fold 7 the cv score is 0.7252163161016602
#
#
#
# At cross fold 8 the cv score is 0.7258496663687564
#
#
#
# At cross fold 9 the cv score is 0.658152803870832
#
#
#
# The model is:
#  ElasticNet()
# At cross fold 2 the cv score is 0.5841318261170517
#
#
#
# At cross fold 3 the cv score is 0.5834826464822808
#
#
#
# At cross fold 4 the cv score is 0.601489412061696
#
#
#
# At cross fold 5 the cv score is 0.5964411900739265
#
#
#
# At cross fold 6 the cv score is 0.5790448549890341
#
#
#
# At cross fold 7 the cv score is 0.5866872478592635
#
#
#
# At cross fold 8 the cv score is 0.5758560645182331
#
#
#
# At cross fold 9 the cv score is 0.4395917160087731

# %% [markdown]
# Random forest is best model with accuracy 89.9% & difference is not much

# %%
rfr.fit(x_train, y_train)
a = rfr.score(x_train, y_train)
pred_train = rfr.predict(x_train)
pred_test_rfr =rfr.predict(x_test)

# %%
plt.figure(figsize = (8,6))
plt.scatter(x = y_test, y = pred_test_rfr, color = 'b')
plt.plot(y_test, y_test, color = 'g')
plt.xlabel('Actual Score: ', fontsize = 14)
plt.ylabel('Predicted Score: ', fontsize = 14)
plt.title('Random forest', fontsize = 18)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# %%
param = {'criterion':['mse','mae'],'max_features':['log2','auto','sqrt'], 'n_estimators' : [10,20,30],'min_samples_split' : [2,4,8]}

# %%
modelrfr = RandomForestRegressor()

# %%
grids = GridSearchCV(modelrfr,param,cv=4)

# %%
rfr=RandomForestRegressor(n_estimators=30,criterion='mse',max_features='sqrt',min_samples_split=2)

# %%
rfr.fit(x_train, y_train)
rfr.score(x_train, y_train)
predrfr = rfr.predict(x_test)

# %%
print('Errors:')
print('\n')
print('Mean absolute error: ', mean_absolute_error(y_test,predrfr))
print('Mean squared error: ', mean_squared_error(y_test,predrfr))
print('Root mean squared error: ', np.sqrt(mean_squared_error(y_test,predrfr)))
print('\n')
print('R2 Score: ', r2_score(y_test,predrfr))
# Out:
# Errors:
#
#
# Mean absolute error:  0.6411769848093998
# Mean squared error:  0.7279099527085127
# Root mean squared error:  0.8531763901494888
#
#
# R2 Score:  0.9079547030566384

# %% [markdown]
# # Model Saving

# %%
import joblib

# %%
joblib.dump(rfr, 'Tempr_frt.obj')
# Out:
# ['Tempr_frt.obj']
