# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('happiness_score_dataset.csv')

# %% [markdown]
# Data is imported via github

# %%
df1
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# Shape of dataset

# %%
df1.shape
# Out:
# (158, 12)

# %% [markdown]
# 158 rows  & 12 columns

# %% [markdown]
# Datatypes present in dataset

# %%
df1.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# Summary of a DataFrame

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# The number of missing values in the dataset

# %%
df1.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df1.set_index('Country',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-57d24afa0d60> in <module>
# ----> 1 df1.set_index('Country',inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['Country'] are in the columns"

# %%
df1.head(10) #  first 10 rows of the dataframe
# Out:
#                                 Region  Happiness Rank  Happiness Score  \
# Country
# Switzerland             Western Europe               1            7.587
# Iceland                 Western Europe               2            7.561
# Denmark                 Western Europe               3            7.527
# Norway                  Western Europe               4            7.522
# Canada                   North America               5            7.427
# Finland                 Western Europe               6            7.406
# Netherlands             Western Europe               7            7.378
# Sweden                  Western Europe               8            7.364
# New Zealand  Australia and New Zealand               9            7.286
# Australia    Australia and New Zealand              10            7.284
#
#              Standard Error  Economy (GDP per Capita)   Family  \
# Country
# Switzerland         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# #find null values

# %%
null_data = df1[df1.isnull().any(axis=1)]

# %%
null_data.head()
# Out:
# Empty DataFrame
# Columns: [Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
df1.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df1['Happiness Score']
# Out:
# Country
# Switzerland    7.587
# Iceland        7.561
# Denmark        7.527
# Norway         7.522
# Canada         7.427
#                ...
# Rwanda         3.465
# Benin          3.340
# Syria          3.006
# Burundi        2.905
# Togo           2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %%
df1['Happiness Score'].sample(3)
# Out:
# Country
# Ethiopia    4.512
# Peru        5.824
# Russia      5.716
# Name: Happiness Score, dtype: float64

# %%
df1['Happiness Score'].head(10)
# Out:
# Country
# Switzerland    7.587
# Iceland        7.561
# Denmark        7.527
# Norway         7.522
# Canada         7.427
# Finland        7.406
# Netherlands    7.378
# Sweden         7.364
# New Zealand    7.286
# Australia      7.284
# Name: Happiness Score, dtype: float64

# %%
df1['Happiness Score'].tail(10)
# Out:
# Country
# Chad            3.667
# Guinea          3.656
# Ivory Coast     3.655
# Burkina Faso    3.587
# Afghanistan     3.575
# Rwanda          3.465
# Benin           3.340
# Syria           3.006
# Burundi         2.905
# Togo            2.839
# Name: Happiness Score, dtype: float64

# %%
df1['Happiness Score'].min()
# Out:
# 2.839

# %%
df1['Happiness Score'].max()
# Out:
# 7.587000000000001

# %% [markdown]
# Data sorting

# %%
df1.sort_values(by="Happiness Score",ascending=True).head(10)
# Out:
#                                        Region  Happiness Rank  \
# Country
# Togo                       Sub-Saharan Africa             158
# Burundi                    Sub-Saharan Africa             157
# Syria         Middle East and Northern Africa             156
# Benin                      Sub-Saharan Africa             155
# Rwanda                     Sub-Saharan Africa             154
# Afghanistan                     Southern Asia             153
# Burkina Faso               Sub-Saharan Africa             152
# Ivory Coast                Sub-Saharan Africa             151
# Guinea                     Sub-Saharan Africa             150
# Chad                       Sub-Saharan Africa             149
#
#               Happiness Score  Standard Error  Economy (GDP per Capita)  \
# Country
# Togo                    2.839         0.06727                   0.20868
# Burundi                 2.905         0.08658                   0.01530
# ...

# %%
df1.sort_values(by="Happiness Score",ascending=False).head(10)
# Out:
#                                 Region  Happiness Rank  Happiness Score  \
# Country
# Switzerland             Western Europe               1            7.587
# Iceland                 Western Europe               2            7.561
# Denmark                 Western Europe               3            7.527
# Norway                  Western Europe               4            7.522
# Canada                   North America               5            7.427
# Finland                 Western Europe               6            7.406
# Netherlands             Western Europe               7            7.378
# Sweden                  Western Europe               8            7.364
# New Zealand  Australia and New Zealand               9            7.286
# Australia    Australia and New Zealand              10            7.284
#
#              Standard Error  Economy (GDP per Capita)   Family  \
# Country
# Switzerland         0.03411                   1.39651  1.34951
# ...

# %%
sns.pairplot(df1.iloc[:,0:-1])

# %%
sns.histplot(df1['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Count'>

# %%
dfb=df1.loc[:,['Happiness Score']]
dfb
# Out:
#              Happiness Score
# Country
# Switzerland            7.587
# Iceland                7.561
# Denmark                7.527
# Norway                 7.522
# Canada                 7.427
# ...                      ...
# Rwanda                 3.465
# Benin                  3.340
# Syria                  3.006
# Burundi                2.905
# Togo                   2.839
#
# [158 rows x 1 columns]

# %%
dfb.shape
# Out:
# (158, 1)
